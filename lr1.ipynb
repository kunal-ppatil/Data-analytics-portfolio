# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('../datasets/Salary_Data_1.csv')

# %%
df.head(10)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %%
df.shape
# Out:
# (30, 2)

# %%
plt.scatter(df['YearsExperience'], df['Salary'])

# %%
plt.scatter(df['YearsExperience'],df['Salary'])
plt.xlim([0,12])
plt.ylim([0, 130000])
# Out:
# (0.0, 130000.0)

# %%
X=df[['YearsExperience']] #2D Dataframe
y=df['Salary']            #1D Series

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %% [markdown]
# ##### fit give data to model for training

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ##### coef give output of slope which is m

# %%
model.coef_
# Out:
# array([9449.96232146])

# %% [markdown]
# ##### its the coefficent C a part where it touches on y-axis

# %%
model.intercept_
# Out:
# 25792.20019866871

# %%
model.predict([[15]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([167541.63502049])
